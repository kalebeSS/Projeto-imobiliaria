# %%
import sys
import os
import pandas as pd

# 1. Configura o caminho para encontrar a pasta src
sys.path.append(os.path.abspath('..'))

# 2. Importa as ferramentas (funções)
from src.data_cleaning import clean_data
from src.analysis import analyze_data
from src.visualization import plot_distribution, plot_correlation_matrix

# 3. Execução do fluxo de dados
# Note o '../' para subir uma pasta e entrar em 'data'
caminho_csv = '../data/imoveis.csv'

# Limpa
cleaned_df = clean_data(caminho_csv)

# Analisa (passando o DF que acabou de ser limpo)
stats, correlation_matrix = analyze_data(cleaned_df)

# Visualiza
plot_distribution(cleaned_df)
plot_correlation_matrix(correlation_matrix)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 11
#       9 from src.data_cleaning import clean_data
#      10 from src.analysis import analyze_data
# ---> 11 from src.visualization import plot_distribution, plot_correlation_matrix
#      13 # 3. Execução do fluxo de dados
#      14 # Note o '../' para subir uma pasta e entrar em 'data'
#      15 caminho_csv = '../data/imoveis.csv'
#
# File c:\COD PYTHON\PORTIFÓLIO\Projeto-imobiliaria\src\visualization.py:20
#      17     plt.savefig('plots/correlation_matrix.png')
#      18     plt.show()
# ---> 20 plot_distribution(cleaned_df)
#      21 plot_correlation_matrix(correlation_matrix)
#
# NameError: name 'cleaned_df' is not defined
